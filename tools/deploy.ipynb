# %% [markdown]
# Documentation: [readme.md](readme.md). The first code cell switches the process **cwd** to **`deploy/`** so `utils.py` imports work whether you start Jupyter from the **repo root** or from **`deploy/`**.
#
# Environment: from the **repository root**, run **`uv sync`** (creates **`.venv/`** at the repo root) then **`uv run jupyter notebook deploy/deploy.ipynb`** (see readme).
#
# **Firmware `.bin`**: store under **`deploy/bin/`** or rely on auto-download inside **`flash_with_esptool`** / **`run_full_flash`** (see readme).
#
# Deployments are **Step 1** (serial flash) and **Step 2** (copy or update firmware on `CIRCUITPY`). Step 2 **chooses automatically**: if **`boot.toml`** already exists on the volume, it runs the **update** path (settings backup + merge + restore); otherwise it runs the **new-board** copy. **Run all** runs Step 1 then Step 2 — only run Step 1 when you need a full CircuitPython reflash.

# %% [markdown]
# ## Configuration
#
# Run the **setup** cell below, then **Serial port** to list USB devices and optionally pick one for **`CFG.serial_port`** (default **`/dev/tty.usbmodem101`**).
#
# You can also edit **`CFG`** directly: `circuitpy_root`, and optional **`circuitpython_bin`** / **`circuitpython_board_id`** / **`circuitpython_locale`** / **`circuitpython_download_fallback_url`**`. Settings backups use **`device_id`** from the device `settings.toml` under **`tools/settings_backups/<device_id>/`**.

# %%
import sys
from pathlib import Path

# So ``import notebook_env`` works from repo root or from deploy/
_repo = Path.cwd().resolve()
_deploy_candidate = _repo if (_repo / "utils.py").is_file() else _repo / "deploy"
if str(_deploy_candidate) not in sys.path:
    sys.path.insert(0, str(_deploy_candidate))

import notebook_env

notebook_env.activate()

from utils import (
    DeployConfig,
    copy_firmware_full,
    flash_with_esptool,
    list_serial_ports,
    pick_serial_port_interactive,
    run_full_flash,
    copy_firmware_update,
)

# Override defaults, e.g. DeployConfig(circuitpy_root=Path("/media/youruser/CIRCUITPY"))  # Linux CIRCUITPY path
CFG = DeployConfig()
CFG

# %% [markdown]
# ### Serial port
#
# Run the next cell to **probe USB serial ports** (requires `pyserial`). It **bootstraps `deploy/`** like the setup cell, so it still works after a **kernel restart** without re-running setup. Type a **number** and Enter to set **`CFG.serial_port`**, or **Enter alone** to keep the current value (default **`/dev/tty.usbmodem101`**). If **`CFG`** does not exist yet, the cell creates it.

# %%
import sys
from pathlib import Path

_repo = Path.cwd().resolve()
_deploy_candidate = _repo if (_repo / "utils.py").is_file() else _repo / "deploy"
if str(_deploy_candidate) not in sys.path:
    sys.path.insert(0, str(_deploy_candidate))

import notebook_env

notebook_env.activate()

from utils import DeployConfig, pick_serial_port_interactive

if "CFG" not in globals():
    CFG = DeployConfig()

pick_serial_port_interactive(CFG)
CFG

# %% [markdown]
# ## Step 1 — Flash the board
#
# Serial flashing only (**`erase_flash`** if enabled, then **`write_flash`**). Resolves a **`.bin`** via **`ensure_circuitpython_bin`** (existing file, `deploy/bin/`, download index, or fallback). Does **not** copy the repo onto **`CIRCUITPY`**.
#
# Use **BOOT + RESET** on ESP32-S3 if the port does not appear. After this step, reset the board and wait until **`CIRCUITPY`** mounts before Step 2 (copy or update).

# %%
flash_with_esptool(CFG)

# %% [markdown]
# ## Step 2 — Copy or update firmware on CIRCUITPY
#
# Run the code cell below after **`CIRCUITPY`** is mounted (reset the board if needed).
#
# - **If `boot.toml` exists** on `CFG.circuitpy_root` → **update** (existing board): same as the former Step 3 — back up `settings.toml` / `startup.toml`, copy the repo **`firmware/`** tree, merge any **new keys** from repo templates into the slot backup, restore settings to the board.
# - **If `boot.toml` is missing** → **new board** (same as the former Step 2): copy **`firmware/`**, copy **`tools/settings.toml`** onto the volume, then re-apply **values** parsed from any previous **`settings.toml`** (e.g. Wi‑Fi credentials). Does **not** use the **`settings_backups/`** snapshot flow (that stays on the update branch).

# %%
_boot = CFG.circuitpy_root / "boot.toml"
if _boot.is_file():
    print(f"Found {_boot} — updating firmware (existing board).", flush=True)
    copy_firmware_update(CFG)
else:
    print(f"No {_boot} — copying firmware tree (new board).", flush=True)
    copy_firmware_full(CFG)
# Out:
# Found /Volumes/CIRCUITPY/boot.toml — updating firmware (existing board).
# Warning: no device_id in /Volumes/CIRCUITPY/settings.toml; using backup folder 'unknown'.
# Removing file blocking deploy: /Users/silvioheinze/coding/firmware/tools/settings_backups/unknown/settings.toml
# Copied /Volumes/CIRCUITPY/settings.toml -> /Users/silvioheinze/coding/firmware/tools/settings_backups/unknown/settings.toml
# Firmware copy: 247 files -> /Volumes/CIRCUITPY
# Firmware copy:   0%|          | 0/247 [00:00<?, ?file/s]
# Removing file blocking deploy: /Volumes/CIRCUITPY/ble_config_tlv.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/ble_status.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/boot.toml
# Removing file blocking deploy: /Volumes/CIRCUITPY/certs/api-sensor-community-chain.pem
# Removing file blocking deploy: /Volumes/CIRCUITPY/certs/isrgrootx1.pem
# Removing file blocking deploy: /Volumes/CIRCUITPY/code.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/config.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/enums.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/ld_service.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/led_controller.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ags02ma.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ahtx0.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/advertising/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/advertising/adafruit.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/advertising/standard.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/attributes/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/characteristics/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/characteristics/float.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/characteristics/int.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/characteristics/json.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/characteristics/stream.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/characteristics/string.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/circuitpython.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/microbit.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/nordic.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/sphero.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/standard/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/standard/device_info.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/services/standard/hid.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ble/uuid/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bme280/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bme280/advanced.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bme280/basic.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bme280/protocol.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bme680.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bmp280.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bmp3xx.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bus_device/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bus_device/i2c_device.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_bus_device/spi_device.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_connection_manager.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ds3231.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/_md5.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/_sha1.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/_sha224.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/_sha256.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/_sha384.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_hashlib/_sha512.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_logging.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/ism330dhcx.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/lsm6ds3.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/lsm6ds33.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/lsm6ds3trc.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/lsm6dso32.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_lsm6ds/lsm6dsox.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ltr390.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_max1704x.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_minimqtt/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_minimqtt/adafruit_minimqtt.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_minimqtt/matcher.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_mlx90640.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ntp.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_pixelbuf.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bcd_alarm.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bcd_alarm.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bcd_datetime.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bcd_datetime.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bit.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bit.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bits.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_bits.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_struct.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_struct.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_struct_array.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/i2c_struct_array.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/register_accessor.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/register_bit.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_register/register_bits.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_requests.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_scd4x.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_sdcard.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_sgp40/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_sgp40/voc_algorithm.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_sht31d.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_sht4x.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_shtc3.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_ticks.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/adafruit_tsl2591.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/core.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/event.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/funcs.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/lock.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/manifest.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/stream.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/task.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/asyncio/traceback.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/bmp581.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/cptoml.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/dirTree.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/lsm6ds3.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/lsm6ds33.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/lsm6ds3trc.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/lsm6dso32.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/lsm6dsox.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/neopixel.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/channel.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/channel_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/i2c_adapter/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/i2c_adapter/i2c_channel.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/i2c_adapter/linux_i2c_channel_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/i2c_adapter/sensor_bridge_i2c_channel_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/i2c_connection_mock.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/i2c_sensor_mock.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/mock_i2c_channel_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/mock_shdlc_channel_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/response_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/shdlc_sensor_mock.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/mocks/shdlc_transceiver_mock.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/multi_channel.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/multi_device_support.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/multi_sensor_bridge.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/rx_tx_data.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/shdlc_adapter/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/shdlc_adapter/shdlc_channel.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/shdlc_adapter/shdlc_serial_channel_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/transfer.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_adapters/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_support_types/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_support_types/bitfield.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_support_types/mixin_access.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_support_types/signals.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_driver_support_types/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/circuitpython_i2c_transceiver.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/circuitpython_i2c_transceiver.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/command.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/command.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/connection.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/connection.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/crc_calculator.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/crc_calculator.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/device.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/device.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/errors.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/errors.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/linux_i2c_transceiver.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/linux_i2c_transceiver.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/sensirion_command.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/sensirion_command.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/transceiver_v1.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/transceiver_v1.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/version.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_driver/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/commands/__init__.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/commands/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/commands/generated.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/commands/generated.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/commands/wrapped.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/commands/wrapped.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/device.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/device.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/measured_values.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/measured_values.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/response_types.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/response_types.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/version.mpy
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen5x/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen62/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen62/commands.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen62/device.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen62/response_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen62/result_types.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen62/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen63c/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen63c/commands.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen63c/device.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen63c/response_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen63c/result_types.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen63c/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen66/__init__.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen66/commands.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen66/device.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen66/response_provider.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen66/result_types.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sensirion_i2c_sen66/version.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/lib/sht30.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/logger.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/main.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/measurement_temp_queue.py
# Removing file blocking deploy: /Volumes/CIRCUITPY/models
# Removing file blocking deploy: /Volumes/CIRCUITPY/settings.toml
# Copied firmware tree /Users/silvioheinze/coding/firmware/firmware -> /Volumes/CIRCUITPY (247 files)
# Settings merge: added 6 key(s) from repo template into backup: MODEL, TEST_MODE, SSID, PASSWORD, SEND_TO_SENSOR_COMMUNITY, WIFILESS_MODE
# Startup merge: no new keys in repo template (backup unchanged).
# Removing file blocking deploy: /Volumes/CIRCUITPY/settings.toml
# Copied /Users/silvioheinze/coding/firmware/tools/settings_backups/unknown/settings.toml -> /Volumes/CIRCUITPY/settings.toml
# Removing file blocking deploy: /Volumes/CIRCUITPY/startup.toml
# Copied /Users/silvioheinze/coding/firmware/tools/settings_backups/unknown/startup.toml -> /Volumes/CIRCUITPY/startup.toml
# Update finished.

# %% [markdown]
# ## Optional — List serial ports
#
# Requires **`pyserial`**. Use the printed device path for **`CFG.serial_port`**.

# %%
list_serial_ports()

# %% [markdown]
# ## Optional — Shortcut for a new board
#
# **`run_full_flash(CFG)`** runs **Step 1** then **`copy_firmware_full`** (equivalent to the **no `boot.toml`** branch of Step 2). Use this **instead** of running the Step 1 and Step 2 cells above; leave the next line commented if you already use those cells, or you will flash twice.

# %%
# run_full_flash(CFG)  # uncomment only if you skip Step 1 and Step 2 cells above
